# %%
import pandas as pd
import numpy as np

# %%
Data = pd.read_csv('winequality-white.csv',sep=';')
Data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
X = Data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']]
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
Y = Data['quality']
Y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state = 0)

# %%
X_train.shape
# Out:
# (3918, 11)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([5.59064994, 5.46612209, 6.08826801, 6.7935377 , 5.97054831,
#        4.15423325, 6.53858017, 6.27153883, 5.94339097, 5.79333728,
#        5.75373171, 5.45667801, 5.13997293, 5.52464742, 6.21729591,
#        5.74754765, 6.31477849, 5.50810327, 6.76247337, 6.17944272,
#        5.91597932, 6.22926151, 5.97536336, 5.91117045, 5.8372182 ,
#        6.4279924 , 4.89423106, 5.19864679, 6.36788167, 5.65392916,
#        5.38257257, 5.79775722, 6.21169274, 6.36035842, 5.38105671,
#        6.14379123, 6.17885898, 5.50015702, 6.21194669, 5.79581071,
#        6.22621364, 5.9667525 , 5.70667088, 5.61747744, 5.39818495,
#        6.55552855, 5.29839102, 6.52852706, 6.50702693, 5.50656612,
#        6.76096171, 6.22691935, 5.40767427, 5.77843246, 6.00322767,
#        6.37586016, 5.69506027, 6.22814781, 5.15773657, 6.56755237,
#        5.65540713, 5.38660498, 6.2676798 , 6.14119576, 6.13779365,
#        6.13882161, 5.62908393, 5.19405853, 5.31762254, 5.67446271,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(Y_test,Y_pred)
r2
# Out:
# 0.25134767611014297

# %%
#cross validation
acc = []
for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state=i)
    model = LinearRegression()
    model.fit(X_train,Y_train)
    Y_pred = model.predict(X_test)
    r2 = r2_score(Y_test,Y_pred)
    acc.append(r2)

# %%
acc
# Out:
# [0.2901221946696403,
#  0.245317426159689,
#  0.283203719111102,
#  0.2842398194878679,
#  0.29480271569776795,
#  0.26049114489199976,
#  0.27786996469464476,
#  0.2697994956315337,
#  0.2753792613639775,
#  0.2742868892098238,
#  0.2880063832931763,
#  0.30209309845633026,
#  0.2546709034370338,
#  0.22573137006826693,
#  0.2582159300187843,
#  0.29921260735147526,
#  0.2963364144584333,
#  0.278076646202585,
#  0.26992775861159657,
#  0.25865427519753303,
#  0.27616871763660833,
#  0.2658848490728364,
#  0.2822057045108578,
#  0.2913563930305906,
#  0.279675455064499,
#  0.285283233889696,
#  0.2852117436432694,
#  0.23776962604186058,
#  0.29175822986743216,
#  0.27373333080967266,
#  0.2543845156751743,
#  0.29526192787897343,
#  0.2884901190495174,
#  0.2801562648541861,
#  0.2837151179787927,
#  0.24173471932652724,
#  0.2933785348982033,
#  0.29697597934929265,
#  0.28161659806259565,
#  0.29177240204947386,
#  0.3226885138692118,
#  0.2652750042179177,
# ...

# %%
acc_arr = np.array(acc)
acc_arr
# Out:
# array([0.29012219, 0.24531743, 0.28320372, 0.28423982, 0.29480272,
#        0.26049114, 0.27786996, 0.2697995 , 0.27537926, 0.27428689,
#        0.28800638, 0.3020931 , 0.2546709 , 0.22573137, 0.25821593,
#        0.29921261, 0.29633641, 0.27807665, 0.26992776, 0.25865428,
#        0.27616872, 0.26588485, 0.2822057 , 0.29135639, 0.27967546,
#        0.28528323, 0.28521174, 0.23776963, 0.29175823, 0.27373333,
#        0.25438452, 0.29526193, 0.28849012, 0.28015626, 0.28371512,
#        0.24173472, 0.29337853, 0.29697598, 0.2816166 , 0.2917724 ,
#        0.32268851, 0.265275  , 0.26647655, 0.277354  , 0.30403262,
#        0.22225448, 0.31488722, 0.29285965, 0.2953554 , 0.28727421,
#        0.27259566, 0.29875971, 0.29155501, 0.30552947, 0.3025835 ,
#        0.25727187, 0.22944736, 0.30324118, 0.212161  , 0.28172232,
#        0.33535167, 0.24618525, 0.25328242, 0.26361002, 0.28918379,
#        0.25872208, 0.30122226, 0.31728128, 0.27750901, 0.27327917,
# ...

# %%
acc_arr.max()
# Out:
# 0.33535167353872886

# %%
acc_arr.argmax()
# Out:
# 60

# %%
Y_train.shape
# Out:
# (3918,)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,Y_train,color = "red",lable="Actual Data")
plt.scatter(X_train,model.predict(X_train),color="blue",label="Predicted Data")
plt.plot(X_train,model.predict(X_train),'--',color="green",label="Line Of Regrassion")
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-715ac50293b1> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(X_train,Y_train,color = "red",lable="Actual Data")
#       3 plt.scatter(X_train,model.predict(X_train),color="blue",label="Predicted Data")
#       4 plt.plot(X_train,model.predict(X_train),'--',color="green",label="Line Of Regrassion")
#       5 plt.legend(loc='best')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2872         verts=cbook.deprecation._deprecated_parameter,
#    2873         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2874     __ret = gca().scatter(
#    2875         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...
